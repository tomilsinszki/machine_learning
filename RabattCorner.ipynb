# %% [markdown]
# ## Initial imports

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai.structured import *
from fastai.column_data import *
np.set_printoptions(threshold=50, edgeitems=20)

PATH='/home/paperspace/data/rc/'

# %% [markdown]
# ## Dataset

# %%
table_names = ['test', 'train', 'validation']

# %%
import dask.dataframe as dd

# %%
# df = dd.read_csv(f'{PATH}rc.csv')
tables = [dd.read_csv(f'{PATH}{fname}.csv') for fname in table_names]

# %%
from IPython.display import HTML, display

# %%
for t in tables: display(t.head())
# Out:
#    start_year  start_month  user_id  signup_year  signup_month  postal0  \
# 0        2019            2        1         2012            12      8.0
# 1        2019            2        1         2012            12      8.0
# 2        2019            2        1         2012            12      8.0
# 3        2019            2        1         2012            12      8.0
# 4        2019            2        1         2012            12      8.0
#
#    postal1  postal2  postal3  gender  language  birthday  partner_id  \
# 0      0.0      5.0      5.0       1         1    1984.0           7
# 1      0.0      5.0      5.0       1         1    1984.0          12
# 2      0.0      5.0      5.0       1         1    1984.0          16
# 3      0.0      5.0      5.0       1         1    1984.0          19
# 4      0.0      5.0      5.0       1         1    1984.0          20
#
#    previous_visit_count  sum_amount
# 0                     2         0.0
# 1                     0         0.0
# 2                     1         0.0
# 3                     0         0.0
# 4                    11         0.0
#    start_year  start_month  user_id  signup_year  signup_month  postal0  \
# 0        2017            1        1         2012            12      8.0
# 1        2017            1        1         2012            12      8.0
# 2        2017            1        1         2012            12      8.0
# 3        2017            1        1         2012            12      8.0
# 4        2017            1        1         2012            12      8.0
#
#    postal1  postal2  postal3  gender  language  birthday  partner_id  \
# 0      0.0      5.0      5.0       1         1    1984.0           7
# 1      0.0      5.0      5.0       1         1    1984.0          12
# 2      0.0      5.0      5.0       1         1    1984.0          16
# 3      0.0      5.0      5.0       1         1    1984.0          19
# 4      0.0      5.0      5.0       1         1    1984.0          20
#
#    previous_visit_count  sum_amount
# 0                     2         0.0
# 1                     0         0.0
# 2                     1         0.0
# 3                     0         0.0
# 4                     8         0.0
#    start_year  start_month  user_id  signup_year  signup_month  postal0  \
# 0        2019            1        1         2012            12      8.0
# 1        2019            1        1         2012            12      8.0
# 2        2019            1        1         2012            12      8.0
# 3        2019            1        1         2012            12      8.0
# 4        2019            1        1         2012            12      8.0
#
#    postal1  postal2  postal3  gender  language  birthday  partner_id  \
# 0      0.0      5.0      5.0       1         1    1984.0           7
# 1      0.0      5.0      5.0       1         1    1984.0          12
# 2      0.0      5.0      5.0       1         1    1984.0          16
# 3      0.0      5.0      5.0       1         1    1984.0          19
# 4      0.0      5.0      5.0       1         1    1984.0          20
#
#    previous_visit_count  sum_amount
# 0                     2         0.0
# 1                     0         0.0
# 2                     1         0.0
# 3                     0         0.0
# 4                    11         0.0

# %%
test, train, validation = tables

# %%
train.head()
# Out:
#    start_year  start_month  user_id  signup_year  signup_month  postal0  \
# 0        2017            1        1         2012            12      8.0
# 1        2017            1        1         2012            12      8.0
# 2        2017            1        1         2012            12      8.0
# 3        2017            1        1         2012            12      8.0
# 4        2017            1        1         2012            12      8.0
#
#    postal1  postal2  postal3  gender  language  birthday  partner_id  \
# 0      0.0      5.0      5.0       1         1    1984.0           7
# 1      0.0      5.0      5.0       1         1    1984.0          12
# 2      0.0      5.0      5.0       1         1    1984.0          16
# 3      0.0      5.0      5.0       1         1    1984.0          19
# 4      0.0      5.0      5.0       1         1    1984.0          20
#
#    previous_visit_count  sum_amount
# 0                     2         0.0
# 1                     0         0.0
# 2                     1         0.0
# 3                     0         0.0
# 4                     8         0.0

# %%
validation.head()
# Out:
#    start_year  start_month  user_id  signup_year  signup_month  postal0  \
# 0        2019            1        1         2012            12      8.0
# 1        2019            1        1         2012            12      8.0
# 2        2019            1        1         2012            12      8.0
# 3        2019            1        1         2012            12      8.0
# 4        2019            1        1         2012            12      8.0
#
#    postal1  postal2  postal3  gender  language  birthday  partner_id  \
# 0      0.0      5.0      5.0       1         1    1984.0           7
# 1      0.0      5.0      5.0       1         1    1984.0          12
# 2      0.0      5.0      5.0       1         1    1984.0          16
# 3      0.0      5.0      5.0       1         1    1984.0          19
# 4      0.0      5.0      5.0       1         1    1984.0          20
#
#    previous_visit_count  sum_amount
# 0                     2         0.0
# 1                     0         0.0
# 2                     1         0.0
# 3                     0         0.0
# 4                    11         0.0

# %%
test.head()
# Out:
#    start_year  start_month  user_id  signup_year  signup_month  postal0  \
# 0        2019            2        1         2012            12      8.0
# 1        2019            2        1         2012            12      8.0
# 2        2019            2        1         2012            12      8.0
# 3        2019            2        1         2012            12      8.0
# 4        2019            2        1         2012            12      8.0
#
#    postal1  postal2  postal3  gender  language  birthday  partner_id  \
# 0      0.0      5.0      5.0       1         1    1984.0           7
# 1      0.0      5.0      5.0       1         1    1984.0          12
# 2      0.0      5.0      5.0       1         1    1984.0          16
# 3      0.0      5.0      5.0       1         1    1984.0          19
# 4      0.0      5.0      5.0       1         1    1984.0          20
#
#    previous_visit_count  sum_amount
# 0                     2         0.0
# 1                     0         0.0
# 2                     1         0.0
# 3                     0         0.0
# 4                    11         0.0

# %%
cat_vars = ['start_year', 'start_month', 'user_id', 'signup_year', 'signup_month', 'postal0', 'postal1', 'postal2', 'postal3', 'gender', 'language', 'birthday', 'partner_id']

contin_vars = ['previous_visit_count']

# %%
dep = 'sum_amount'

# %%
#joined = df[cat_vars+contin_vars+[dep]].copy()

# %%
#joined.head()

# %%
#joined_test[dep] = 0.0
